# %% [markdown]
# # US EPA Air Quality System API Example
# This example illustrates how to request data from the US Environmental Protection Agency (EPA) Air Quality Service (AQS) API. This is a historical API and does not provide real-time air quality data. The [documentation](https://aqs.epa.gov/aqsweb/documents/data_api.html) for the API provides definitions of the different call parameter and examples of the various calls that can be made to the API.
#
# This notebook works systematically through example calls, requesting an API key, using 'list' to get various IDs and parameter values, and using 'daily summary' to get summary data that meets specific condistions. The notebook contains example function definitions that could be reused in other code. In general, the notebook explains each step along the way, referring back to possible output. Some of the explanations are tailored to the specific example requests of the API. Changing values to explore the results of the API is probably useful, but that will result in some explanations being out of sync with the outputs.
#
# The US EPA was created in the early 1970's. The EPA reports that they only started broad based monitoring with standardized quality assurance procedures in the 1980's. Many counties will have data starting somewhere between 1983 and 1988. However, some counties still do not have any air quality monitoring stations. The API helps resolve this by providing calls to search for monitoring stations and data using either station ids, or a county designation or a geographic bounding box. This example code provides examples of the county based and bounding box based API calls. Some [additional information on the Air Quality System can be found in the EPA FAQ](https://www.epa.gov/outdoor-air-quality-data/frequent-questions-about-airdata) on the system.
#
# The end goal of this example is to get to some values that we might use for the Air Quality Index or AQI. You might see this reported on the news, most often around smog, but more frequently with regard to smoke. The AQI index is meant to tell us something about how healthy or clean the air is on any day. The AQI is actually a somewhat complext measure. When I started this example I looked up [how to calculate the AQI](https://www.airnow.gov/sites/default/files/2020-05/aqi-technical-assistance-document-sept2018.pdf) so that I would know roughly what goes into that value.
#
#
# ## License
# This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.2 - August 16, 2024

# %%
# 
#    These are standard python modules
#
#import json, time, urllib.parse
import json, time
#
#    The 'requests' module is a distribution module for making web requests. If you do not have it already, you'll need to install it
import requests
import pandas as pd
# Out:
# /var/folders/js/_m5r698x29j4dvr0w18h6jdm0000gn/T/ipykernel_61764/4071512226.py:9: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
with open('intermediate_file_paths.json') as output_path_file:
    output_paths = json.load(output_path_file)


EPA_AQI_OUTPUT_PATH = output_paths.get('stage0_epa_aqi_csv')

# %%
#########
#
#    CONSTANTS
#
CITY_LOCATIONS = {

    'memphis': {'city': 'Memphis',
        'county': 'Shelby',
        'state': 'Tennessee',
        'fips': '47157',
        'latlon': [35.11, -89.97]},  # Decimal degrees (35.11, -89.97
    
}
#
#    This is the root of all AQS API URLs
#
API_REQUEST_URL = 'https://aqs.epa.gov/data/api'

#
#    These are some of the 'actions' we can ask the API to take or requests that we can make of the API
#
#    Sign-up request - generally only performed once - unless you lose your key
API_ACTION_SIGNUP = '/signup?email={email}'
#
#    List actions provide information on API parameter values that are required by some other actions/requests
API_ACTION_LIST_CLASSES = '/list/classes?email={email}&key={key}'
API_ACTION_LIST_PARAMS = '/list/parametersByClass?email={email}&key={key}&pc={pclass}'
API_ACTION_LIST_SITES = '/list/sitesByCounty?email={email}&key={key}&state={state}&county={county}'
#
#    Monitor actions are requests for monitoring stations that meet specific criteria
API_ACTION_MONITORS_COUNTY = '/monitors/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_MONITORS_BOX = '/monitors/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
#    Summary actions are requests for summary data. These are for daily summaries
API_ACTION_DAILY_SUMMARY_COUNTY = '/dailyData/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_DAILY_SUMMARY_BOX = '/dailyData/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'

API_ACTION_ANNUAL_SUMMARY_COUNTY = '/annualData/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'



#
#    It is always nice to be respectful of a free data resource.
#    We're going to observe a 100 requests per minute limit - which is fairly nice
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED
#
#
#    This is a template that covers most of the parameters for the actions we might take, from the set of actions
#    above. In the examples below, most of the time parameters can either be supplied as individual values to a
#    function - or they can be set in a copy of the template and passed in with the template.
# 
AQS_REQUEST_TEMPLATE = {
    "email":      "",     
    "key":        "",      
    "state":      "",     # the two digit state FIPS # as a string
    "county":     "",     # the three digit county FIPS # as a string
    "begin_date": "",     # the start of a time window in YYYYMMDD format
    "end_date":   "",     # the end of a time window in YYYYMMDD format, begin_date and end_date must be in the same year
    "minlat":    0.0,
    "maxlat":    0.0,
    "minlon":    0.0,
    "maxlon":    0.0,
    "param":     "",     # a list of comma separated 5 digit codes, max 5 codes requested
    "pclass":    ""      # parameter class is only used by the List calls
}

# %% [markdown]
# ## Example 1. Making a sign-up request
#
# Before you can use the API you need to request a key. You will use an email address to make the request. The EPA then sends a confirmation email link and a 'key' that you use for all other requests.
#
# You only need to sign-up once, unless you want to invalidate your current key (by getting a new key) or you lose your key.

# %%
#
#    This implements the sign-up request. The parameters are standardized so that this function definition matches
#    all of the others. However, the easiest way to call this is to simply call this function with your preferred
#    email address.
#
def request_signup(email_address = None,
                   endpoint_url = API_REQUEST_URL, 
                   endpoint_action = API_ACTION_SIGNUP, 
                   request_template = AQS_REQUEST_TEMPLATE,
                   headers = None):
    
    # Make sure we have a string - if you don't have access to this email addres, things might go badly for you
    if email_address:
        request_template['email'] = email_address        
    
    if not request_template['email']: 
        raise Exception("Must supply an email address to call 'request_signup()'")

    if '@' not in request_template['email']: 
        raise Exception(f"Must supply an email address to call 'request_signup()'. The string '{request_template['email']}' does not look like an email address.")

    # Compose the signup url - create a request URL by combining the endpoint_url with the parameters for the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#    A SIGNUP request is only to be done once, to request a key. A key is sent to that email address and needs to be confirmed with a click through
#    This code should probably be commented out after you've made your key request to make sure you don't accidentally make a new sign-up request

# print("Requesting SIGNUP ...")
# USERNAME = "djsdavis@uw.edu"
# response = request_signup(USERNAME)
# print(json.dumps(response,indent=4))

# %% [markdown]
# **Note:** The code below relies on a user module called apikeys that is a key manager. You don't need that to make this code work. You can use the email you used for your sign-up request and the key that you got in email. Assign your email address to "USERNAME" and your key to "APIKEY" as constants and the remaining cells in the notbook should work.

# %%
# Load the config file
with open('proj_config.json') as config_file:
    config = json.load(config_file)

# Get the username and access token
username_api_auth = config.get('api_username')

if not username_api_auth:
    raise Exception("API email address not found in config file")

api_key = config.get('apikey')

if not api_key:
    raise Exception("API key not found in config file")


USERNAME = username_api_auth
APIKEY = api_key


#
#   Note: if you don't want to use the key manager to help manage your API keys, you can specify the values as constants
#   below. Just don't distribute the notebook without removing the constants or you'll be distributing your key too.
#
#USERNAME = "<the_email_address_you_sent_on_signup>"
#APIKEY = "<the_key_the_EPA_sent_you_in_email>"

# %% [markdown]
# ## Example 2. Making a list request
# Once you have a key, the next thing is to get information about the different types of air quality monitoring (sensors) and the different places where we might find air quality stations. The monitoring system is complex and changes all the time. The EPA implementation allows an API user to find changes to monitoring sites and sensors by making requests - maybe monthly, or daily. This API approach is probably better than having the EPA publish documentation that may be out of date as soon as it hits a web page. The one problem here is that some of the responses rely on jargon or terms-of-art. That is, one needs to know a bit about the way atmospheric sciece works to understand some of the terms. ... Good thing we can use the web to search for terms we don't know!

# %%
#
#    This implements the list request. There are several versions of the list request that only require email and key.
#    This code sets the default action/requests to list the groups or parameter class descriptors. Having those descriptors 
#    allows one to request the individual (proprietary) 5 digit codes for individual air quality measures by using the
#    param request. Some code in later cells will illustrate those requests.
#
def request_list_info(email_address = None, key = None,
                      endpoint_url = API_REQUEST_URL, 
                      endpoint_action = API_ACTION_LIST_CLASSES, 
                      request_template = AQS_REQUEST_TEMPLATE,
                      headers = None):
    
    #  Make sure we have email and key - at least
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    
    # For the basic request we need an email address and a key
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_list_info()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_list_info()'")

    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
#   The default should get us a list of the various groups or classes of sensors. These classes are user defined names for clustors of
#   sensors that might be part of a package or default air quality sensing station. We need a class name to start getting down to the
#   a sensor ID. Each sensor type has an ID number. We'll eventually need those ID numbers to be able to request values that come from
#   that specific sensor.
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY

response = request_list_info(request_template=request_data)

if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "code": "AIRNOW MAPS",
#         "value_represented": "The parameters represented on AirNow maps (88101, 88502, and 44201)"
#     },
#     {
#         "code": "ALL",
#         "value_represented": "Select all Parameters Available"
#     },
#     {
#         "code": "AQI POLLUTANTS",
#         "value_represented": "Pollutants that have an AQI Defined"
#     },
#     {
#         "code": "CORE_HAPS",
#         "value_represented": "Urban Air Toxic Pollutants"
#     },
#     {
#         "code": "CRITERIA",
#         "value_represented": "Criteria Pollutants"
#     },
#     {
#         "code": "CSN DART",
#         "value_represented": "List of CSN speciation parameters to populate the STI DART tool"
#     },
#     {
#         "code": "FORECAST",
#         "value_represented": "Parameters routinely extracted by AirNow (STI)"
#     },
#     {
#         "code": "HAPS",
#         "value_represented": "Hazardous Air Pollutants"
#     },
#     {
#         "code": "IMPROVE CARBON",
#         "value_represented": "IMPROVE Carbon Parameters"
#     },
#     {
#         "code": "IMPROVE_SPECIATION",
#         "value_represented": "PM2.5 Speciated Parameters Measured at IMPROVE sites"
#     },
#     {
#         "code": "MET",
#         "value_represented": "Meteorological Parameters"
#     },
#     {
#         "code": "NATTS CORE HAPS",
#         "value_represented": "The core list of toxics of interest to the NATTS program."
#     },
#     {
#         "code": "NATTS REQUIRED",
#         "value_represented": "Required compounds to be collected in the National Air Toxics Network"
#     },
#     {
#         "code": "PAMS",
#         "value_represented": "Photochemical Assessment Monitoring System"
#     },
#     {
#         "code": "PAMS_VOC",
#         "value_represented": "Volatile Organic Compound subset of the PAMS Parameters"
#     },
#     {
#         "code": "PM COARSE",
#         "value_represented": "PM between 2.5 and 10 micrometers"
#     },
#     {
#         "code": "PM10 SPECIATION",
#         "value_represented": "PM10 Speciated Parameters"
#     },
#     {
#         "code": "PM2.5 CONT NONREF",
#         "value_represented": "PM2.5 Continuous, Nonreference Methods"
#     },
#     {
#         "code": "PM2.5 MASS/QA",
#         "value_represented": "PM2.5 Mass and QA Parameters"
#     },
#     {
#         "code": "SCHOOL AIR TOXICS",
#         "value_represented": "School Air Toxics Program Parameters"
#     },
#     {
#         "code": "SPECIATION",
#         "value_represented": "PM2.5 Speciated Parameters"
#     },
#     {
#         "code": "SPECIATION CARBON",
#         "value_represented": "PM2.5 Speciation Carbon Parameters"
#     },
#     {
#         "code": "SPECIATION CATION/ANION",
#         "value_represented": "PM2.5 Speciation Cation/Anion Parameters"
#     },
#     {
#         "code": "SPECIATION METALS",
#         "value_represented": "PM2.5 Speciation Metal Parameters"
#     },
#     {
#         "code": "UATMP CARBONYL",
#         "value_represented": "Urban Air Toxics Monitoring Program Carbonyls"
#     },
#     {
#         "code": "UATMP VOC",
#         "value_represented": "Urban Air Toxics Monitoring Program VOCs"
#     },
#     {
#         "code": "VOC",
#         "value_represented": "Volatile organic compounds"
#     }
# ]

# %% [markdown]
# We're interested in getting to something that might be the Air Quality Index (AQI). You see this reported on the news - often around smog values, but also when there is smoke in the sky. The AQI is a complex measure of different gasses and of the particles in the air (dust, dirt, ash ...).
#
# From the list produced by our 'list/Classes' request above, it looks like there is a class of sensors called "AQI POLLUTANTS". Let's try to get a list of those specific sensors and see what we can get from those.

# %%
#
#   Once we have a list of the classes or groups of possible sensors, we can find the sensor IDs that make up that class (group)
#   The one that looks to be associated with the Air Quality Index is "AQI POLLUTANTS"
#   We'll use that to make another list request.
#
AQI_PARAM_CLASS = "AQI POLLUTANTS"

# %%
#
#   Structure a request to get the sensor IDs associated with the AQI
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['pclass'] = AQI_PARAM_CLASS  # here we specify that we want this 'pclass' or parameter classs

response = request_list_info(request_template=request_data, endpoint_action=API_ACTION_LIST_PARAMS)

if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "code": "42101",
#         "value_represented": "Carbon monoxide"
#     },
#     {
#         "code": "42401",
#         "value_represented": "Sulfur dioxide"
#     },
#     {
#         "code": "42602",
#         "value_represented": "Nitrogen dioxide (NO2)"
#     },
#     {
#         "code": "44201",
#         "value_represented": "Ozone"
#     },
#     {
#         "code": "81102",
#         "value_represented": "PM10 Total 0-10um STP"
#     },
#     {
#         "code": "88101",
#         "value_represented": "PM2.5 - Local Conditions"
#     },
#     {
#         "code": "88502",
#         "value_represented": "Acceptable PM2.5 AQI & Speciation Mass"
#     }
# ]

# %% [markdown]
# We should now have (above) a response containing a set of sensor ID numbers. The list should include the sensor numbers as well as a description or name for each sensor.
#
# The EPA AQS API has limits on some call parameters. Specifically, when we request data for sensors we can only specify a maximum of 5 different sensor values to return. This means we cannot get all of the Air Quality Index parameters in one request for data. We have to break it up.
#
# What I did below was to break the request into two logical groups, the AQI sensors that sample gasses and the AQI sensors that sample particles in the air.

# %%
#
#   Given the set of sensor codes, now we can create a parameter list or 'param' value as defined by the AQS API spec.
#   It turns out that we want all of these measures for AQI, but we need to have two different param constants to get
#   all seven of the code types. We can only have a max of 5 sensors/values request per param.
#
#   Gaseous AQI pollutants CO, SO2, NO2, and O2
AQI_PARAMS_GASEOUS = "42101,42401,42602,44201"
#
#   Particulate AQI pollutants PM10, PM2.5, and Acceptable PM2.5
AQI_PARAMS_PARTICULATES = "81102,88101,88502"
#   
#

# %% [markdown]
# Air quality monitoring stations are located all over the US at different locations. We will need some sample locations to experiment with different locations to see what kinds of values come back from different sensor requests.
#
# This list includes the [FIPS](https://www.census.gov/library/reference/code-lists/ansi.html) number for the state and county as a 5 digit string. This format, the 5 digit string, is a 'old' format that is still widely used. There are new codes that may eventually be adopted for the US government information systems. But FIPS is currently what the AQS uses, so that's what is in the list as the constant.
#
# Just two example cities to explore.

# %%
#
#  This list request should give us a list of all the monitoring stations in the county specified by the
#  given city selected from the CITY_LOCATIONS dictionary
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['state'] = CITY_LOCATIONS['memphis']['fips'][:2]   # the first two digits (characters) of FIPS is the state code
request_data['county'] = CITY_LOCATIONS['memphis']['fips'][2:]  # the last three digits (characters) of FIPS is the county code

response = request_list_info(request_template=request_data, endpoint_action=API_ACTION_LIST_SITES)

if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "code": "0001",
#         "value_represented": null
#     },
#     {
#         "code": "0002",
#         "value_represented": null
#     },
#     {
#         "code": "0003",
#         "value_represented": null
#     },
#     {
#         "code": "0004",
#         "value_represented": null
#     },
#     {
#         "code": "0005",
#         "value_represented": null
#     },
#     {
#         "code": "0006",
#         "value_represented": null
#     },
#     {
#         "code": "0007",
#         "value_represented": null
#     },
#     {
#         "code": "0008",
#         "value_represented": null
#     },
#     {
#         "code": "0009",
#         "value_represented": null
#     },
#     {
#         "code": "0010",
#         "value_represented": null
#     },
#     {
#         "code": "0012",
#         "value_represented": null
#     },
#     {
#         "code": "0013",
#         "value_represented": null
#     },
#     {
#         "code": "0014",
#         "value_represented": null
#     },
#     {
#         "code": "0016",
#         "value_represented": "Gas Service Center collocated PM 10s"
#     },
#     {
#         "code": "0017",
#         "value_represented": null
#     },
#     {
#         "code": "0018",
#         "value_represented": null
#     },
#     {
#         "code": "0019",
#         "value_represented": null
#     },
#     {
#         "code": "0020",
#         "value_represented": null
#     },
#     {
#         "code": "0021",
#         "value_represented": "Frayser Ozone Monitor"
#     },
#     {
#         "code": "0022",
#         "value_represented": null
#     },
#     {
#         "code": "0023",
#         "value_represented": null
#     },
#     {
#         "code": "0024",
#         "value_represented": "Alabama Ave. Station"
#     },
#     {
#         "code": "0025",
#         "value_represented": null
#     },
#     {
#         "code": "0026",
#         "value_represented": null
#     },
#     {
#         "code": "0027",
#         "value_represented": null
#     },
#     {
#         "code": "0030",
#         "value_represented": null
#     },
#     {
#         "code": "0031",
#         "value_represented": null
#     },
#     {
#         "code": "0032",
#         "value_represented": null
#     },
#     {
#         "code": "0033",
#         "value_represented": null
#     },
#     {
#         "code": "0034",
#         "value_represented": null
#     },
#     {
#         "code": "0035",
#         "value_represented": null
#     },
#     {
#         "code": "0036",
#         "value_represented": null
#     },
#     {
#         "code": "0037",
#         "value_represented": null
#     },
#     {
#         "code": "0038",
#         "value_represented": null
#     },
#     {
#         "code": "0039",
#         "value_represented": null
#     },
#     {
#         "code": "0040",
#         "value_represented": null
#     },
#     {
#         "code": "0041",
#         "value_represented": null
#     },
#     {
#         "code": "0042",
#         "value_represented": null
#     },
#     {
#         "code": "0043",
#         "value_represented": null
#     },
#     {
#         "code": "0044",
#         "value_represented": null
#     },
#     {
#         "code": "0045",
#         "value_represented": null
#     },
#     {
#         "code": "0046",
#         "value_represented": "NEAR ILLINIOS CENTRAL RAIL AND MEMPHIS LIGHT AND GAS SUBSTATION"
#     },
#     {
#         "code": "0047",
#         "value_represented": "GUTHRIE CLINIC PM 2.5"
#     },
#     {
#         "code": "0075",
#         "value_represented": "Memphis NCORE site"
#     },
#     {
#         "code": "0080",
#         "value_represented": null
#     },
#     {
#         "code": "0081",
#         "value_represented": null
#     },
#     {
#         "code": "0100",
#         "value_represented": "Near Road Site at Southwest Tennessee Community College"
#     },
#     {
#         "code": "1001",
#         "value_represented": null
#     },
#     {
#         "code": "1002",
#         "value_represented": null
#     },
#     {
#         "code": "1003",
#         "value_represented": null
#     },
#     {
#         "code": "1004",
#         "value_represented": "Edmund Orgill Park Ozone"
#     },
#     {
#         "code": "1032",
#         "value_represented": null
#     },
#     {
#         "code": "1033",
#         "value_represented": null
#     },
#     {
#         "code": "1034",
#         "value_represented": null
#     },
#     {
#         "code": "2001",
#         "value_represented": null
#     },
#     {
#         "code": "2005",
#         "value_represented": null
#     },
#     {
#         "code": "3001",
#         "value_represented": null
#     }
# ]

# %% [markdown]
# Given our CITY_LOCATIONS constant we can now find which monitoring locations are nearby. One option is to use the county to define the area we're interest in. You can get the EPA to list their monitoring stations by county. You can also get a set of monitoring stations by using a bounding box of latitude, longitude points. For this example, we'll use the county approach. There is a bounding box example later in this notebook.

# %% [markdown]
# The above response gives us a list of monitoring stations. Each monitoring station has a unique "code" which is a string number, and, sometimes, a description. The description seems to be something about where the monitoring station is located.

# %% [markdown]
# ## Example 3. Making a daily summary request
#
# The function below is designed to encapsulate requests to the EPA AQS API. When calling the function one should create/copy a parameter template, then initialize that template with values that won't change with each call. Then on each call simply pass in the parameters that need to change, like date ranges.
#
# Another function below provides an example of extracting values and restructuring the response to make it a little more usable.

# %%
#
#    This implements the daily summary request. Daily summary provides a daily summary value for each sensor being requested
#    from the start date to the end date. 
#
#    Like the two other functions, this can be called with a mixture of a defined parameter dictionary, or with function
#    parameters. If function parameters are provided, those take precedence over any parameters from the request template.
#
def request_summary(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = None, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_daily_summary()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_daily_summary()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_daily_summary()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_daily_summary()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_daily_summary()'")
    # Note we're not validating FIPS fields because not all of the daily summary actions require the FIPS numbers
        
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
#    This is a list of field names - data - that will be extracted from each record
#
EXTRACTION_FIELDS = ['sample_duration','observation_count','arithmetic_mean','aqi']

#
#    The function creates a summary record
def extract_summary_from_response(r=None, fields=EXTRACTION_FIELDS):
    ## the result will be structured around monitoring site, parameter, and then date
    result = dict()
    data = r["Data"]
    for record in data:
        # make sure the record is set up
        site = record['site_number']
        param = record['parameter_code']
        #date = record['date_local']    # this version keeps the respnse value YYYY-
        date = record['date_local'].replace('-','') # this puts it in YYYYMMDD format
        if site not in result:
            result[site] = dict()
            result[site]['local_site_name'] = record['local_site_name']
            result[site]['site_address'] = record['site_address']
            result[site]['state'] = record['state']
            result[site]['county'] = record['county']
            result[site]['city'] = record['city']
            result[site]['pollutant_type'] = dict()
        if param not in result[site]['pollutant_type']:
            result[site]['pollutant_type'][param] = dict()
            result[site]['pollutant_type'][param]['parameter_name'] = record['parameter']
            result[site]['pollutant_type'][param]['units_of_measure'] = record['units_of_measure']
            result[site]['pollutant_type'][param]['method'] = record['method']
            result[site]['pollutant_type'][param]['data'] = dict()
        if date not in result[site]['pollutant_type'][param]['data']:
            result[site]['pollutant_type'][param]['data'][date] = list()
        
        # now extract the specified fields
        extract = dict()
        for k in fields:
            if str(k) in record:
                extract[str(k)] = record[k]
            else:
                # this makes sure we always have the requested fields, even if
                # we have a missing value for a given day/month
                extract[str(k)] = None
        
        # add this extraction to the list for the day
        result[site]['pollutant_type'][param]['data'][date].append(extract)
    
    return result

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_GASEOUS
request_data['state'] = CITY_LOCATIONS['memphis']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['memphis']['fips'][2:]


all_gaseous = {}

for year in range(1961, 2022):

    # GET THE GASEAOUS AQI Responses

    # request daily summary data for the month of July in 2021
    gaseous_aqi = request_summary(request_template=request_data, begin_date=f"{year}0101", end_date=f"{year}1231", endpoint_action=API_ACTION_DAILY_SUMMARY_COUNTY)
    #gaseous_aqi = request_summary(request_template=request_data, begin_date=f"{year}0101", end_date=f"{year}1231", endpoint_action=API_ACTION_DAILY_SUMMARY_COUNTY)
    print(f"Response for the gaseous pollutants for {year}...")
    #print(gaseous_aqi["Header"])
    #
    if gaseous_aqi["Header"][0]['status'] == "Success":
        print("gaseous_aqi header success")
        #print(json.dumps(gaseous_aqi['Data'],indent=4)
    elif gaseous_aqi["Header"][0]['status'].startswith("No data "):
        print("Looks like the gaseous response generated no data. You might take a closer look at your request and the response data.")
    else:
        #print(json.dumps(gaseous_aqi,indent=4))
        print(gaseous_aqi["Header"])


    extract_gaseous_year = extract_summary_from_response(gaseous_aqi)
    all_gaseous[year] = extract_gaseous_year  # Store in dictionary with year as key
# Out:
# Response for the gaseous pollutants for 1961...
# Looks like the gaseous response generated no data. You might take a closer look at your request and the response data.
# Response for the gaseous pollutants for 1962...
# Looks like the gaseous response generated no data. You might take a closer look at your request and the response data.
# Response for the gaseous pollutants for 1963...
# Looks like the gaseous response generated no data. You might take a closer look at your request and the response data.
# Response for the gaseous pollutants for 1964...
# Looks like the gaseous response generated no data. You might take a closer look at your request and the response data.
# Response for the gaseous pollutants for 1965...
# Looks like the gaseous response generated no data. You might take a closer look at your request and the response data.
# Response for the gaseous pollutants for 1966...
# Looks like the gaseous response generated no data. You might take a closer look at your request and the response data.
# Response for the gaseous pollutants for 1967...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1968...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1969...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1970...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1971...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1972...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1973...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1974...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1975...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1976...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1977...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1978...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1979...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1980...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1981...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1982...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1983...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1984...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1985...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1986...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1987...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1988...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1989...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1990...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1991...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1992...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1993...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1994...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1995...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1996...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1997...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1998...
# gaseous_aqi header success
# Response for the gaseous pollutants for 1999...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2000...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2001...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2002...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2003...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2004...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2005...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2006...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2007...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2008...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2009...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2010...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2011...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2012...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2013...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2014...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2015...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2016...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2017...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2018...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2019...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2020...
# gaseous_aqi header success
# Response for the gaseous pollutants for 2021...
# gaseous_aqi header success

# %%
# Initialize counters for non-null 'aqi' values and total 'aqi' records
aqi_non_null_count = 0
total_records = 0

# Iterate through the 'all_gaseous' dictionary to count non-null 'aqi' values and total records
for year_data in all_gaseous.values():
    for site_info in year_data.values():
        for pollutant_info in site_info['pollutant_type'].values():
            for daily_data in pollutant_info['data'].values():
                for record in daily_data:
                    total_records += 1  # Increment total count for each 'aqi' record
                    if record.get('aqi') is not None:
                        aqi_non_null_count += 1  # Increment non-null count only if 'aqi' is not None

# Display the total counts
print(f"Total 'aqi' records in all_gaseous: {total_records}")
print(f"Total non-null 'aqi' values in all_gaseous: {aqi_non_null_count}")
# Out:
# Total 'aqi' records in all_gaseous: 466173
# Total non-null 'aqi' values in all_gaseous: 276613

# %% [markdown]
# # Particulate Data

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_GASEOUS
request_data['state'] = CITY_LOCATIONS['memphis']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['memphis']['fips'][2:]


all_particulate = {}

for year in range(1961, 2022):

    # GET THE PARTICULATE AQI RESPONSES

    request_data['param'] = AQI_PARAMS_PARTICULATES
    # request daily summary data for the month of July in 2021
    particulate_aqi = request_summary(request_template=request_data, begin_date=f"{year}0101", end_date=f"{year}1231", endpoint_action=API_ACTION_DAILY_SUMMARY_COUNTY)
    print(f"Response for the particulate pollutants for {year}...")
    
    #
    if particulate_aqi["Header"][0]['status'] == "Success":
        print("particulate_aqi header success")
        #print(json.dumps(particulate_aqi['Data'],indent=4))
    
    elif particulate_aqi["Header"][0]['status'].startswith("No data "):
        print("Looks like the particulate response generated no data. You might take a closer look at your request and the response data.")

    else:
        #print(json.dumps(particulate_aqi,indent=4))
        print(particulate_aqi["Header"])

    extract_particulate_year = extract_summary_from_response(particulate_aqi)
    all_particulate[year] = extract_particulate_year  # Store in dictionary with year as key

    # print("Summary of particulate extraction ...")
    # print(json.dumps(extract_particulate_year,indent=4))



# extract_gaseous = extract_summary_from_response(gaseous_aqi)
# print("Summary of gaseous extraction ...")
# print(json.dumps(extract_gaseous,indent=4))

# extract_particulate = extract_summary_from_response(particulate_aqi)
# print("Summary of particulate extraction ...")
# print(json.dumps(extract_particulate,indent=4))
# Out:
# Response for the particulate pollutants for 1961...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1962...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1963...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1964...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1965...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1966...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1967...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1968...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1969...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1970...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1971...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1972...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1973...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1974...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1975...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1976...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1977...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1978...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1979...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1980...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1981...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1982...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1983...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1984...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1985...
# Looks like the particulate response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants for 1986...
# particulate_aqi header success
# Response for the particulate pollutants for 1987...
# particulate_aqi header success
# Response for the particulate pollutants for 1988...
# particulate_aqi header success
# Response for the particulate pollutants for 1989...
# particulate_aqi header success
# Response for the particulate pollutants for 1990...
# particulate_aqi header success
# Response for the particulate pollutants for 1991...
# particulate_aqi header success
# Response for the particulate pollutants for 1992...
# particulate_aqi header success
# Response for the particulate pollutants for 1993...
# particulate_aqi header success
# Response for the particulate pollutants for 1994...
# particulate_aqi header success
# Response for the particulate pollutants for 1995...
# particulate_aqi header success
# Response for the particulate pollutants for 1996...
# particulate_aqi header success
# Response for the particulate pollutants for 1997...
# particulate_aqi header success
# Response for the particulate pollutants for 1998...
# particulate_aqi header success
# Response for the particulate pollutants for 1999...
# particulate_aqi header success
# Response for the particulate pollutants for 2000...
# particulate_aqi header success
# Response for the particulate pollutants for 2001...
# particulate_aqi header success
# Response for the particulate pollutants for 2002...
# particulate_aqi header success
# Response for the particulate pollutants for 2003...
# particulate_aqi header success
# Response for the particulate pollutants for 2004...
# particulate_aqi header success
# Response for the particulate pollutants for 2005...
# particulate_aqi header success
# Response for the particulate pollutants for 2006...
# particulate_aqi header success
# Response for the particulate pollutants for 2007...
# particulate_aqi header success
# Response for the particulate pollutants for 2008...
# particulate_aqi header success
# Response for the particulate pollutants for 2009...
# particulate_aqi header success
# Response for the particulate pollutants for 2010...
# particulate_aqi header success
# Response for the particulate pollutants for 2011...
# particulate_aqi header success
# Response for the particulate pollutants for 2012...
# particulate_aqi header success
# Response for the particulate pollutants for 2013...
# particulate_aqi header success
# Response for the particulate pollutants for 2014...
# particulate_aqi header success
# Response for the particulate pollutants for 2015...
# particulate_aqi header success
# Response for the particulate pollutants for 2016...
# particulate_aqi header success
# Response for the particulate pollutants for 2017...
# particulate_aqi header success
# Response for the particulate pollutants for 2018...
# particulate_aqi header success
# Response for the particulate pollutants for 2019...
# particulate_aqi header success
# Response for the particulate pollutants for 2020...
# particulate_aqi header success
# Response for the particulate pollutants for 2021...
# particulate_aqi header success

# %%
# Initialize counters for non-null 'aqi' values and total 'aqi' records
aqi_non_null_count_particulate = 0
total_records = 0

# Iterate through the 'all_gaseous' dictionary to count non-null 'aqi' values and total records
for year_data in all_particulate.values():
    for site_info in year_data.values():
        for pollutant_info in site_info['pollutant_type'].values():
            for daily_data in pollutant_info['data'].values():
                for record in daily_data:
                    total_records += 1  # Increment total count for each 'aqi' record
                    if record.get('aqi') is not None:
                        aqi_non_null_count_particulate += 1  # Increment non-null count only if 'aqi' is not None

# Display the total counts
print(f"Total 'aqi' records in all_gaseous: {total_records}")
print(f"Total non-null 'aqi' values in all_gaseous: {aqi_non_null_count_particulate}")
# Out:
# Total 'aqi' records in all_gaseous: 147539
# Total non-null 'aqi' values in all_gaseous: 131219

# %%
# Flatten extraction data function (unchanged)
def flatten_extraction_data(extraction_data_list):
    flat_data = []
    for extraction_data in extraction_data_list:  # Loop over each dictionary in the list
        for site_code, site_info in extraction_data.items():
            site_name = site_info.get('local_site_name')
            for pollutant_number, pollutant_info in site_info['pollutant_type'].items():
                pollutant_name = pollutant_info.get('parameter_name')
                for local_date, daily_data in pollutant_info['data'].items():
                    for record in daily_data:
                        if record.get('aqi') is not None:
                            flat_data.append({
                                'site_code': site_code,
                                'site_name': site_name,
                                'pollutant_number': pollutant_number,
                                'pollutant_name': pollutant_name,
                                'local_date': local_date,
                                'aqi': record['aqi']
                            })
    return flat_data

# Flatten both all_gaseous and all_particulate data
gaseous_flat = flatten_extraction_data(all_gaseous.values())
particulate_flat = flatten_extraction_data(all_particulate.values())

# Combine into a single DataFrame
combined_flat_data = gaseous_flat + particulate_flat
epa_aqi_df = pd.DataFrame(combined_flat_data)

# Display the resulting DataFrame
print(epa_aqi_df.head())
# Out:
#   site_code site_name pollutant_number  pollutant_name local_date  aqi
# 0      0019      None            42401  Sulfur dioxide   19670102   29
# 1      0019      None            42401  Sulfur dioxide   19670102   29
# 2      0019      None            42401  Sulfur dioxide   19670103   29
# 3      0019      None            42401  Sulfur dioxide   19670103   29
# 4      0019      None            42401  Sulfur dioxide   19670105   29

# %%
num_rows = len(epa_aqi_df)
print(f"Number of rows in df: {num_rows}")
# Out:
# Number of rows in df: 407832

# %%
epa_aqi_df.to_csv(EPA_AQI_OUTPUT_PATH, index=False)

# %% [markdown]
# ## Didn't work
#
# Annual Summary API Response doesn't include AQI data

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_GASEOUS
request_data['state'] = CITY_LOCATIONS['memphis']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['memphis']['fips'][2:]

# request daily summary data for the month of July in 2021
gaseous_aqi = request_summary(request_template=request_data, begin_date="20210701", end_date="20210731", endpoint_action=API_ACTION_ANNUAL_SUMMARY_COUNTY)
print("Response for the gaseous pollutants ...")
#
if gaseous_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(gaseous_aqi['Data'],indent=4))
elif gaseous_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(gaseous_aqi,indent=4))

request_data['param'] = AQI_PARAMS_PARTICULATES
# request daily summary data for the month of July in 2021
particulate_aqi = request_summary(request_template=request_data, begin_date="20210701", end_date="20210731", endpoint_action=API_ACTION_ANNUAL_SUMMARY_COUNTY)
print("Response for the particulate pollutants ...")
#
if particulate_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(particulate_aqi['Data'],indent=4))
elif particulate_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(particulate_aqi,indent=4))
# Out:
# Response for the gaseous pollutants ...
# [
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0021",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 35.217501,
#         "longitude": -90.019707,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "metric_used": "Daily maxima of observed hourly values (between 9:00 AM and 8:00 PM)",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 5584,
#         "observation_percent": 99.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 243,
#         "required_day_count": 245,
#         "exceptional_data_count": 0,
#         "null_observation_count": 296,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.045082,
#         "standard_deviation": 0.011113,
#         "first_max_value": 0.088,
#         "first_max_datetime": "2021-09-10 15:00",
#         "second_max_value": 0.074,
#         "second_max_datetime": "2021-06-17 16:00",
#         "third_max_value": 0.074,
#         "third_max_datetime": "2021-08-24 13:00",
#         "fourth_max_value": 0.073,
#         "fourth_max_datetime": "2021-09-07 12:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.074,
#         "ninety_eighth_percentile": 0.072,
#         "ninety_fifth_percentile": 0.065,
#         "ninetieth_percentile": 0.058,
#         "seventy_fifth_percentile": 0.052,
#         "fiftieth_percentile": 0.045,
#         "tenth_percentile": 0.031,
#         "local_site_name": "Frayser Ozone Monitor",
#         "site_address": "1330 FRAYSER BLVD",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0021",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 35.217501,
#         "longitude": -90.019707,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 5830,
#         "observation_percent": 99.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 242,
#         "required_day_count": 245,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.040095,
#         "standard_deviation": 0.01057,
#         "first_max_value": 0.069,
#         "first_max_datetime": "2021-06-17 10:00",
#         "second_max_value": 0.069,
#         "second_max_datetime": "2021-09-10 10:00",
#         "third_max_value": 0.068,
#         "third_max_datetime": "2021-06-16 10:00",
#         "fourth_max_value": 0.067,
#         "fourth_max_datetime": "2021-06-14 10:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.068,
#         "ninety_eighth_percentile": 0.064,
#         "ninety_fifth_percentile": 0.059,
#         "ninetieth_percentile": 0.053,
#         "seventy_fifth_percentile": 0.048,
#         "fiftieth_percentile": 0.04,
#         "tenth_percentile": 0.027,
#         "local_site_name": "Frayser Ozone Monitor",
#         "site_address": "1330 FRAYSER BLVD",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0021",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 35.217501,
#         "longitude": -90.019707,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 5830,
#         "observation_percent": 99.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 242,
#         "required_day_count": 245,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.040095,
#         "standard_deviation": 0.01057,
#         "first_max_value": 0.069,
#         "first_max_datetime": "2021-06-17 10:00",
#         "second_max_value": 0.069,
#         "second_max_datetime": "2021-09-10 10:00",
#         "third_max_value": 0.068,
#         "third_max_datetime": "2021-06-16 10:00",
#         "fourth_max_value": 0.067,
#         "fourth_max_datetime": "2021-06-14 10:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.068,
#         "ninety_eighth_percentile": 0.064,
#         "ninety_fifth_percentile": 0.059,
#         "ninetieth_percentile": 0.053,
#         "seventy_fifth_percentile": 0.048,
#         "fiftieth_percentile": 0.04,
#         "tenth_percentile": 0.027,
#         "local_site_name": "Frayser Ozone Monitor",
#         "site_address": "1330 FRAYSER BLVD",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0021",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 35.217501,
#         "longitude": -90.019707,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "metric_used": "Daily maximum of 8-hour running average",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 4134,
#         "observation_percent": 98.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 241,
#         "required_day_count": 245,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.040008,
#         "standard_deviation": 0.010633,
#         "first_max_value": 0.069,
#         "first_max_datetime": "2021-06-17 10:00",
#         "second_max_value": 0.069,
#         "second_max_datetime": "2021-09-10 10:00",
#         "third_max_value": 0.068,
#         "third_max_datetime": "2021-06-16 10:00",
#         "fourth_max_value": 0.067,
#         "fourth_max_datetime": "2021-06-14 10:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.068,
#         "ninety_eighth_percentile": 0.064,
#         "ninety_fifth_percentile": 0.059,
#         "ninetieth_percentile": 0.053,
#         "seventy_fifth_percentile": 0.048,
#         "fiftieth_percentile": 0.04,
#         "tenth_percentile": 0.027,
#         "local_site_name": "Frayser Ozone Monitor",
#         "site_address": "1330 FRAYSER BLVD",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "42401",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Sulfur dioxide",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "SO2 1-hour 2010",
#         "metric_used": "Daily maximum 1-hour average",
#         "method": "Instrumental - Ultraviolet Fluorescence API 100 EU",
#         "year": 2021,
#         "units_of_measure": "Parts per billion",
#         "event_type": "No Events",
#         "observation_count": 8461,
#         "observation_percent": 97.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 356,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 299,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": null,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.726685,
#         "standard_deviation": 0.467045,
#         "first_max_value": 2.8,
#         "first_max_datetime": "2021-02-13 22:00",
#         "second_max_value": 2.8,
#         "second_max_datetime": "2021-10-08 14:00",
#         "third_max_value": 2.7,
#         "third_max_datetime": "2021-02-18 14:00",
#         "fourth_max_value": 2.4,
#         "fourth_max_datetime": "2021-06-13 09:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 2.4,
#         "ninety_eighth_percentile": 1.9,
#         "ninety_fifth_percentile": 1.6,
#         "ninetieth_percentile": 1.3,
#         "seventy_fifth_percentile": 0.9,
#         "fiftieth_percentile": 0.7,
#         "tenth_percentile": 0.2,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2022-03-16"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "42602",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Nitrogen dioxide (NO2)",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "NO2 1-hour 2010",
#         "metric_used": "Daily Maximum 1-hour average",
#         "method": "Teledyne Model T500U - Cavity Attenuated Phase Shift Spectroscopy",
#         "year": 2021,
#         "units_of_measure": "Parts per billion",
#         "event_type": "No Events",
#         "observation_count": 2182,
#         "observation_percent": 25.0,
#         "validity_indicator": "N",
#         "valid_day_count": 92,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 26,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": null,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 9.981522,
#         "standard_deviation": 4.993049,
#         "first_max_value": 25.1,
#         "first_max_datetime": "2021-07-05 02:00",
#         "second_max_value": 25.0,
#         "second_max_datetime": "2021-07-03 21:00",
#         "third_max_value": 21.0,
#         "third_max_datetime": "2021-07-31 19:00",
#         "fourth_max_value": 20.3,
#         "fourth_max_datetime": "2021-07-04 21:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 25.1,
#         "ninety_eighth_percentile": 25.0,
#         "ninety_fifth_percentile": 19.2,
#         "ninetieth_percentile": 16.6,
#         "seventy_fifth_percentile": 13.1,
#         "fiftieth_percentile": 8.8,
#         "tenth_percentile": 5.0,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-22"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "42101",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Carbon monoxide",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "CO 1-hour 1971",
#         "metric_used": "Obseved hourly values",
#         "method": "INSTRUMENTAL - Gas Filter Correlation Teledyne API 300 EU / T300U",
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 8351,
#         "observation_percent": 95.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 365,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 409,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.194174,
#         "standard_deviation": 0.09034,
#         "first_max_value": 0.986,
#         "first_max_datetime": "2021-11-06 23:00",
#         "second_max_value": 0.933,
#         "second_max_datetime": "2021-10-12 06:00",
#         "third_max_value": 0.924,
#         "third_max_datetime": "2021-10-12 07:00",
#         "fourth_max_value": 0.821,
#         "fourth_max_datetime": "2021-10-17 05:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.546,
#         "ninety_eighth_percentile": 0.474,
#         "ninety_fifth_percentile": 0.376,
#         "ninetieth_percentile": 0.306,
#         "seventy_fifth_percentile": 0.219,
#         "fiftieth_percentile": 0.166,
#         "tenth_percentile": 0.121,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2022-03-16"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "42101",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Carbon monoxide",
#         "sample_duration_code": "Z",
#         "sample_duration": "8-HR RUN AVG END HOUR",
#         "pollutant_standard": "CO 8-hour 1971",
#         "metric_used": "8-Hour running average (end hour) of observed hourly values",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 8701,
#         "observation_percent": 99.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 365,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.194702,
#         "standard_deviation": 0.084572,
#         "first_max_value": 0.7,
#         "first_max_datetime": "2021-03-03 07:00",
#         "second_max_value": 0.7,
#         "second_max_datetime": "2021-03-03 08:00",
#         "third_max_value": 0.7,
#         "third_max_datetime": "2021-11-07 01:00",
#         "fourth_max_value": 0.7,
#         "fourth_max_datetime": "2021-11-07 02:00",
#         "first_max_nonoverlap_value": 0.7,
#         "first_max_n_o_datetime": "2021-03-03 07:00",
#         "second_max_nonoverlap_value": 0.7,
#         "second_max_n_o_datetime": "2021-11-07 01:00",
#         "ninety_ninth_percentile": 0.5,
#         "ninety_eighth_percentile": 0.4,
#         "ninety_fifth_percentile": 0.3,
#         "ninetieth_percentile": 0.3,
#         "seventy_fifth_percentile": 0.2,
#         "fiftieth_percentile": 0.2,
#         "tenth_percentile": 0.1,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2022-03-16"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "42401",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Sulfur dioxide",
#         "sample_duration_code": "Y",
#         "sample_duration": "3-HR BLK AVG",
#         "pollutant_standard": "SO2 3-hour 1971",
#         "metric_used": "3-Hour block average of observed hourly values",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Parts per billion",
#         "event_type": "No Events",
#         "observation_count": 2789,
#         "observation_percent": 96.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 352,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": null,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.388634,
#         "standard_deviation": 0.334264,
#         "first_max_value": 2.4,
#         "first_max_datetime": "2021-02-18 14:00",
#         "second_max_value": 2.4,
#         "second_max_datetime": "2021-02-18 17:00",
#         "third_max_value": 2.4,
#         "third_max_datetime": "2021-02-18 20:00",
#         "fourth_max_value": 2.3,
#         "fourth_max_datetime": "2021-02-18 11:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 1.3,
#         "ninety_eighth_percentile": 1.2,
#         "ninety_fifth_percentile": 1.0,
#         "ninetieth_percentile": 0.9,
#         "seventy_fifth_percentile": 0.6,
#         "fiftieth_percentile": 0.4,
#         "tenth_percentile": 0.0,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2022-03-16"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "42401",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Sulfur dioxide",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "SO2 24-hour 1971",
#         "metric_used": "Daily Average of observed values",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Parts per billion",
#         "event_type": "No Events",
#         "observation_count": 356,
#         "observation_percent": 98.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 356,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": null,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.410674,
#         "standard_deviation": 0.313002,
#         "first_max_value": 1.9,
#         "first_max_datetime": "2021-02-18 00:00",
#         "second_max_value": 1.3,
#         "second_max_datetime": "2021-02-13 00:00",
#         "third_max_value": 1.3,
#         "third_max_datetime": "2021-02-19 00:00",
#         "fourth_max_value": 1.2,
#         "fourth_max_datetime": "2021-02-15 00:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 1.2,
#         "ninety_eighth_percentile": 1.1,
#         "ninety_fifth_percentile": 1.0,
#         "ninetieth_percentile": 0.9,
#         "seventy_fifth_percentile": 0.6,
#         "fiftieth_percentile": 0.4,
#         "tenth_percentile": 0.0,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2022-03-16"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "42401",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Sulfur dioxide",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "SO2 Annual 1971",
#         "metric_used": "Observed Values",
#         "method": "Instrumental - Ultraviolet Fluorescence API 100 EU",
#         "year": 2021,
#         "units_of_measure": "Parts per billion",
#         "event_type": "No Events",
#         "observation_count": 8461,
#         "observation_percent": 97.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 356,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 299,
#         "primary_exceedance_count": null,
#         "secondary_exceedance_count": null,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.409432,
#         "standard_deviation": 0.350459,
#         "first_max_value": 2.8,
#         "first_max_datetime": "2021-02-13 22:00",
#         "second_max_value": 2.8,
#         "second_max_datetime": "2021-10-08 14:00",
#         "third_max_value": 2.7,
#         "third_max_datetime": "2021-02-18 14:00",
#         "fourth_max_value": 2.6,
#         "fourth_max_datetime": "2021-02-18 11:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 1.4,
#         "ninety_eighth_percentile": 1.2,
#         "ninety_fifth_percentile": 1.1,
#         "ninetieth_percentile": 0.9,
#         "seventy_fifth_percentile": 0.6,
#         "fiftieth_percentile": 0.4,
#         "tenth_percentile": 0.0,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2022-03-16"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "42602",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Nitrogen dioxide (NO2)",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "NO2 Annual 1971",
#         "metric_used": "Observed values",
#         "method": "Teledyne Model T500U - Cavity Attenuated Phase Shift Spectroscopy",
#         "year": 2021,
#         "units_of_measure": "Parts per billion",
#         "event_type": "No Events",
#         "observation_count": 2182,
#         "observation_percent": 25.0,
#         "validity_indicator": "N",
#         "valid_day_count": 92,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 26,
#         "primary_exceedance_count": null,
#         "secondary_exceedance_count": null,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 4.706645,
#         "standard_deviation": 3.49017,
#         "first_max_value": 25.1,
#         "first_max_datetime": "2021-07-05 02:00",
#         "second_max_value": 25.0,
#         "second_max_datetime": "2021-07-03 21:00",
#         "third_max_value": 21.0,
#         "third_max_datetime": "2021-07-31 19:00",
#         "fourth_max_value": 20.5,
#         "fourth_max_datetime": "2021-07-31 17:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 16.9,
#         "ninety_eighth_percentile": 14.9,
#         "ninety_fifth_percentile": 12.1,
#         "ninetieth_percentile": 9.5,
#         "seventy_fifth_percentile": 6.0,
#         "fiftieth_percentile": 3.7,
#         "tenth_percentile": 1.5,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-22"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "metric_used": "Daily maxima of observed hourly values (between 9:00 AM and 8:00 PM)",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 8163,
#         "observation_percent": 98.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 357,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 597,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.044336,
#         "standard_deviation": 0.012306,
#         "first_max_value": 0.095,
#         "first_max_datetime": "2021-07-29 13:00",
#         "second_max_value": 0.09,
#         "second_max_datetime": "2021-06-17 14:00",
#         "third_max_value": 0.082,
#         "third_max_datetime": "2021-09-07 15:00",
#         "fourth_max_value": 0.076,
#         "fourth_max_datetime": "2021-06-13 17:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.076,
#         "ninety_eighth_percentile": 0.075,
#         "ninety_fifth_percentile": 0.066,
#         "ninetieth_percentile": 0.059,
#         "seventy_fifth_percentile": 0.052,
#         "fiftieth_percentile": 0.042,
#         "tenth_percentile": 0.03,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 8509,
#         "observation_percent": 96.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 351,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": 1,
#         "secondary_exceedance_count": 1,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.039946,
#         "standard_deviation": 0.011554,
#         "first_max_value": 0.085,
#         "first_max_datetime": "2021-07-29 09:00",
#         "second_max_value": 0.082,
#         "second_max_datetime": "2021-06-17 09:00",
#         "third_max_value": 0.073,
#         "third_max_datetime": "2021-06-14 09:00",
#         "fourth_max_value": 0.071,
#         "fourth_max_datetime": "2021-09-07 10:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.071,
#         "ninety_eighth_percentile": 0.065,
#         "ninety_fifth_percentile": 0.059,
#         "ninetieth_percentile": 0.055,
#         "seventy_fifth_percentile": 0.048,
#         "fiftieth_percentile": 0.038,
#         "tenth_percentile": 0.026,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 2008",
#         "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 8509,
#         "observation_percent": 96.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 351,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": 2,
#         "secondary_exceedance_count": 2,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.039946,
#         "standard_deviation": 0.011554,
#         "first_max_value": 0.085,
#         "first_max_datetime": "2021-07-29 09:00",
#         "second_max_value": 0.082,
#         "second_max_datetime": "2021-06-17 09:00",
#         "third_max_value": 0.073,
#         "third_max_datetime": "2021-06-14 09:00",
#         "fourth_max_value": 0.071,
#         "fourth_max_datetime": "2021-09-07 10:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.071,
#         "ninety_eighth_percentile": 0.065,
#         "ninety_fifth_percentile": 0.059,
#         "ninetieth_percentile": 0.055,
#         "seventy_fifth_percentile": 0.048,
#         "fiftieth_percentile": 0.038,
#         "tenth_percentile": 0.026,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-hour 2015",
#         "metric_used": "Daily maximum of 8-hour running average",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 6034,
#         "observation_percent": 96.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 351,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": 4,
#         "secondary_exceedance_count": 4,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.039809,
#         "standard_deviation": 0.011771,
#         "first_max_value": 0.085,
#         "first_max_datetime": "2021-07-29 09:00",
#         "second_max_value": 0.082,
#         "second_max_datetime": "2021-06-17 09:00",
#         "third_max_value": 0.073,
#         "third_max_datetime": "2021-06-14 09:00",
#         "fourth_max_value": 0.071,
#         "fourth_max_datetime": "2021-09-07 10:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.071,
#         "ninety_eighth_percentile": 0.065,
#         "ninety_fifth_percentile": 0.059,
#         "ninetieth_percentile": 0.055,
#         "seventy_fifth_percentile": 0.048,
#         "fiftieth_percentile": 0.038,
#         "tenth_percentile": 0.026,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0100",
#         "parameter_code": "42602",
#         "poc": 1,
#         "latitude": 35.16126,
#         "longitude": -89.87065,
#         "datum": "WGS84",
#         "parameter": "Nitrogen dioxide (NO2)",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "NO2 1-hour 2010",
#         "metric_used": "Daily Maximum 1-hour average",
#         "method": "Instrumental - Chemiluminescence Teledyne API 200 EU/501",
#         "year": 2021,
#         "units_of_measure": "Parts per billion",
#         "event_type": "No Events",
#         "observation_count": 8183,
#         "observation_percent": 93.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 357,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 577,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": null,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 17.883193,
#         "standard_deviation": 8.5915,
#         "first_max_value": 48.5,
#         "first_max_datetime": "2021-03-04 19:00",
#         "second_max_value": 40.7,
#         "second_max_datetime": "2021-02-20 04:00",
#         "third_max_value": 40.3,
#         "third_max_datetime": "2021-02-24 21:00",
#         "fourth_max_value": 38.7,
#         "fourth_max_datetime": "2021-04-12 22:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 38.7,
#         "ninety_eighth_percentile": 34.8,
#         "ninety_fifth_percentile": 32.2,
#         "ninetieth_percentile": 28.3,
#         "seventy_fifth_percentile": 23.9,
#         "fiftieth_percentile": 18.2,
#         "tenth_percentile": 5.9,
#         "local_site_name": "Near Road Site at Southwest Tennessee Community College",
#         "site_address": "5767 Macon Cove (Near Road Site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-22"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0100",
#         "parameter_code": "42101",
#         "poc": 1,
#         "latitude": 35.16126,
#         "longitude": -89.87065,
#         "datum": "WGS84",
#         "parameter": "Carbon monoxide",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "CO 1-hour 1971",
#         "metric_used": "Obseved hourly values",
#         "method": "Multiple Methods Used",
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 8058,
#         "observation_percent": 92.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 358,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 702,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.285541,
#         "standard_deviation": 0.141875,
#         "first_max_value": 1.018,
#         "first_max_datetime": "2021-10-16 22:00",
#         "second_max_value": 1.013,
#         "second_max_datetime": "2021-11-14 22:00",
#         "third_max_value": 0.996,
#         "third_max_datetime": "2021-11-15 00:00",
#         "fourth_max_value": 0.986,
#         "fourth_max_datetime": "2021-10-16 21:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.732,
#         "ninety_eighth_percentile": 0.672,
#         "ninety_fifth_percentile": 0.572,
#         "ninetieth_percentile": 0.492,
#         "seventy_fifth_percentile": 0.358,
#         "fiftieth_percentile": 0.245,
#         "tenth_percentile": 0.147,
#         "local_site_name": "Near Road Site at Southwest Tennessee Community College",
#         "site_address": "5767 Macon Cove (Near Road Site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2023-03-08"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0100",
#         "parameter_code": "42101",
#         "poc": 1,
#         "latitude": 35.16126,
#         "longitude": -89.87065,
#         "datum": "WGS84",
#         "parameter": "Carbon monoxide",
#         "sample_duration_code": "Z",
#         "sample_duration": "8-HR RUN AVG END HOUR",
#         "pollutant_standard": "CO 8-hour 1971",
#         "metric_used": "8-Hour running average (end hour) of observed hourly values",
#         "method": "Multiple Methods Used",
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 8425,
#         "observation_percent": 96.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 359,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.287193,
#         "standard_deviation": 0.119038,
#         "first_max_value": 0.9,
#         "first_max_datetime": "2021-10-17 03:00",
#         "second_max_value": 0.9,
#         "second_max_datetime": "2021-10-17 04:00",
#         "third_max_value": 0.9,
#         "third_max_datetime": "2021-10-17 05:00",
#         "fourth_max_value": 0.8,
#         "fourth_max_datetime": "2021-10-17 02:00",
#         "first_max_nonoverlap_value": 0.9,
#         "first_max_n_o_datetime": "2021-10-17 03:00",
#         "second_max_nonoverlap_value": 0.8,
#         "second_max_n_o_datetime": "2021-11-15 02:00",
#         "ninety_ninth_percentile": 0.6,
#         "ninety_eighth_percentile": 0.6,
#         "ninety_fifth_percentile": 0.5,
#         "ninetieth_percentile": 0.5,
#         "seventy_fifth_percentile": 0.4,
#         "fiftieth_percentile": 0.3,
#         "tenth_percentile": 0.2,
#         "local_site_name": "Near Road Site at Southwest Tennessee Community College",
#         "site_address": "5767 Macon Cove (Near Road Site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2023-03-08"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0100",
#         "parameter_code": "42602",
#         "poc": 1,
#         "latitude": 35.16126,
#         "longitude": -89.87065,
#         "datum": "WGS84",
#         "parameter": "Nitrogen dioxide (NO2)",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "NO2 Annual 1971",
#         "metric_used": "Observed values",
#         "method": "Instrumental - Chemiluminescence Teledyne API 200 EU/501",
#         "year": 2021,
#         "units_of_measure": "Parts per billion",
#         "event_type": "No Events",
#         "observation_count": 8183,
#         "observation_percent": 93.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 357,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 577,
#         "primary_exceedance_count": null,
#         "secondary_exceedance_count": null,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 8.82174,
#         "standard_deviation": 6.770894,
#         "first_max_value": 48.5,
#         "first_max_datetime": "2021-03-04 19:00",
#         "second_max_value": 45.5,
#         "second_max_datetime": "2021-03-04 18:00",
#         "third_max_value": 40.7,
#         "third_max_datetime": "2021-02-20 04:00",
#         "fourth_max_value": 40.3,
#         "fourth_max_datetime": "2021-02-24 21:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 27.7,
#         "ninety_eighth_percentile": 25.4,
#         "ninety_fifth_percentile": 21.6,
#         "ninetieth_percentile": 18.4,
#         "seventy_fifth_percentile": 13.2,
#         "fiftieth_percentile": 7.3,
#         "tenth_percentile": 1.5,
#         "local_site_name": "Near Road Site at Southwest Tennessee Community College",
#         "site_address": "5767 Macon Cove (Near Road Site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-22"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "1004",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 35.378153,
#         "longitude": -89.83447,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "metric_used": "Daily maxima of observed hourly values (between 9:00 AM and 8:00 PM)",
#         "method": "INSTRUMENTAL - ULTRA VIOLET ABSORPTION",
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 5582,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 244,
#         "required_day_count": 245,
#         "exceptional_data_count": 0,
#         "null_observation_count": 298,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.045459,
#         "standard_deviation": 0.010497,
#         "first_max_value": 0.08,
#         "first_max_datetime": "2021-06-17 16:00",
#         "second_max_value": 0.075,
#         "second_max_datetime": "2021-07-11 00:00",
#         "third_max_value": 0.073,
#         "third_max_datetime": "2021-06-18 12:00",
#         "fourth_max_value": 0.07,
#         "fourth_max_datetime": "2021-09-26 15:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.073,
#         "ninety_eighth_percentile": 0.069,
#         "ninety_fifth_percentile": 0.061,
#         "ninetieth_percentile": 0.059,
#         "seventy_fifth_percentile": 0.052,
#         "fiftieth_percentile": 0.046,
#         "tenth_percentile": 0.032,
#         "local_site_name": "Edmund Orgill Park Ozone",
#         "site_address": "6855 MUDVILLE RD.",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Millington",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "1004",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 35.378153,
#         "longitude": -89.83447,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "metric_used": "Daily maximum of 8 hour running average of observed hourly values",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 5837,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 244,
#         "required_day_count": 245,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 0.041074,
#         "standard_deviation": 0.010121,
#         "first_max_value": 0.071,
#         "first_max_datetime": "2021-06-17 10:00",
#         "second_max_value": 0.066,
#         "second_max_datetime": "2021-06-14 10:00",
#         "third_max_value": 0.063,
#         "third_max_datetime": "2021-06-13 09:00",
#         "fourth_max_value": 0.063,
#         "fourth_max_datetime": "2021-06-18 08:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 0.063,
#         "ninety_eighth_percentile": 0.062,
#         "ninety_fifth_percentile": 0.057,
#         "ninetieth_percentile": 0.053,
#         "seventy_fifth_percentile": 0.048,
#         "fiftieth_percentile": 0.041,
#         "tenth_percentile": 0.028,
# ...
#         "ninetieth_percentile": 13.2,
#         "seventy_fifth_percentile": 10.0,
#         "fiftieth_percentile": 6.8,
#         "tenth_percentile": 4.3,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0100",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 35.16126,
#         "longitude": -89.87065,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 24-hour 2024",
#         "metric_used": "Daily Mean",
#         "method": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "year": 2021,
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 119,
#         "observation_percent": 98.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 119,
#         "required_day_count": 122,
#         "exceptional_data_count": 0,
#         "null_observation_count": 3,
#         "primary_exceedance_count": 0,
#         "secondary_exceedance_count": 0,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 7.956303,
#         "standard_deviation": 3.907699,
#         "first_max_value": 25.5,
#         "first_max_datetime": "2021-08-02 00:00",
#         "second_max_value": 24.5,
#         "second_max_datetime": "2021-07-21 00:00",
#         "third_max_value": 18.2,
#         "third_max_datetime": "2021-07-30 00:00",
#         "fourth_max_value": 18.0,
#         "fourth_max_datetime": "2021-08-08 00:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 24.5,
#         "ninety_eighth_percentile": 18.2,
#         "ninety_fifth_percentile": 15.5,
#         "ninetieth_percentile": 12.7,
#         "seventy_fifth_percentile": 10.1,
#         "fiftieth_percentile": 6.9,
#         "tenth_percentile": 4.2,
#         "local_site_name": "Near Road Site at Southwest Tennessee Community College",
#         "site_address": "5767 Macon Cove (Near Road Site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-18"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0024",
#         "parameter_code": "88101",
#         "poc": 2,
#         "latitude": 35.151194,
#         "longitude": -90.041559,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "metric_used": "Quarterly Means of Daily Means",
#         "method": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "year": 2021,
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 29,
#         "observation_percent": 97.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 29,
#         "required_day_count": 30,
#         "exceptional_data_count": 0,
#         "null_observation_count": 2,
#         "primary_exceedance_count": 10,
#         "secondary_exceedance_count": 4,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 8.848276,
#         "standard_deviation": 5.523885,
#         "first_max_value": 25.0,
#         "first_max_datetime": "2021-08-02 00:00",
#         "second_max_value": 23.8,
#         "second_max_datetime": "2021-07-21 00:00",
#         "third_max_value": 16.3,
#         "third_max_datetime": "2021-11-06 00:00",
#         "fourth_max_value": 15.2,
#         "fourth_max_datetime": "2021-02-03 00:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 25.0,
#         "ninety_eighth_percentile": 25.0,
#         "ninety_fifth_percentile": 23.8,
#         "ninetieth_percentile": 16.3,
#         "seventy_fifth_percentile": 9.5,
#         "fiftieth_percentile": 8.1,
#         "tenth_percentile": 3.8,
#         "local_site_name": "Alabama Ave. Station",
#         "site_address": "416 ALABAMA AVENUE",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-18"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0024",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 35.151194,
#         "longitude": -90.041559,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "metric_used": "Quarterly Means of Daily Means",
#         "method": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "year": 2021,
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 118,
#         "observation_percent": 96.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 117,
#         "required_day_count": 122,
#         "exceptional_data_count": 0,
#         "null_observation_count": 6,
#         "primary_exceedance_count": 45,
#         "secondary_exceedance_count": 6,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 8.430508,
#         "standard_deviation": 4.074216,
#         "first_max_value": 25.5,
#         "first_max_datetime": "2021-08-02 00:00",
#         "second_max_value": 25.0,
#         "second_max_datetime": "2021-07-21 00:00",
#         "third_max_value": 18.7,
#         "third_max_datetime": "2021-07-30 00:00",
#         "fourth_max_value": 17.2,
#         "fourth_max_datetime": "2021-02-09 00:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 25.0,
#         "ninety_eighth_percentile": 18.7,
#         "ninety_fifth_percentile": 15.9,
#         "ninetieth_percentile": 13.1,
#         "seventy_fifth_percentile": 10.7,
#         "fiftieth_percentile": 7.8,
#         "tenth_percentile": 4.2,
#         "local_site_name": "Alabama Ave. Station",
#         "site_address": "416 ALABAMA AVENUE",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-18"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "88101",
#         "poc": 2,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "metric_used": "Quarterly Means of Daily Means",
#         "method": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "year": 2021,
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 120,
#         "observation_percent": 98.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 119,
#         "required_day_count": 122,
#         "exceptional_data_count": 0,
#         "null_observation_count": 4,
#         "primary_exceedance_count": null,
#         "secondary_exceedance_count": null,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 7.554167,
#         "standard_deviation": 3.810752,
#         "first_max_value": 24.6,
#         "first_max_datetime": "2021-08-02 00:00",
#         "second_max_value": 23.2,
#         "second_max_datetime": "2021-07-21 00:00",
#         "third_max_value": 18.1,
#         "third_max_datetime": "2021-08-08 00:00",
#         "fourth_max_value": 17.9,
#         "fourth_max_datetime": "2021-07-30 00:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 23.2,
#         "ninety_eighth_percentile": 18.1,
#         "ninety_fifth_percentile": 14.4,
#         "ninetieth_percentile": 11.8,
#         "seventy_fifth_percentile": 9.7,
#         "fiftieth_percentile": 6.7,
#         "tenth_percentile": 3.6,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "metric_used": "Quarterly Means of Daily Means",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "Events Included",
#         "observation_count": 361,
#         "observation_percent": 99.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 361,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": null,
#         "secondary_exceedance_count": null,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 9.234626,
#         "standard_deviation": 4.23734,
#         "first_max_value": 29.4,
#         "first_max_datetime": "2021-08-02 00:00",
#         "second_max_value": 26.3,
#         "second_max_datetime": "2021-07-05 00:00",
#         "third_max_value": 26.3,
#         "third_max_datetime": "2021-07-21 00:00",
#         "fourth_max_value": 26.3,
#         "fourth_max_datetime": "2021-07-22 00:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 26.3,
#         "ninety_eighth_percentile": 21.5,
#         "ninety_fifth_percentile": 17.7,
#         "ninetieth_percentile": 14.5,
#         "seventy_fifth_percentile": 11.0,
#         "fiftieth_percentile": 8.0,
#         "tenth_percentile": 5.2,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0075",
#         "parameter_code": "88101",
#         "poc": 23,
#         "latitude": 35.151699,
#         "longitude": -89.850249,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "metric_used": "Quarterly Means of Daily Means",
#         "method": null,
#         "year": 2021,
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 361,
#         "observation_percent": 99.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 361,
#         "required_day_count": 365,
#         "exceptional_data_count": 0,
#         "null_observation_count": 0,
#         "primary_exceedance_count": null,
#         "secondary_exceedance_count": null,
#         "certification_indicator": "Certification not required",
#         "arithmetic_mean": 8.066759,
#         "standard_deviation": 4.131438,
#         "first_max_value": 28.5,
#         "first_max_datetime": "2021-08-02 00:00",
#         "second_max_value": 25.4,
#         "second_max_datetime": "2021-07-21 00:00",
#         "third_max_value": 25.4,
#         "third_max_datetime": "2021-07-22 00:00",
#         "fourth_max_value": 25.3,
#         "fourth_max_datetime": "2021-07-05 00:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 25.3,
#         "ninety_eighth_percentile": 20.3,
#         "ninety_fifth_percentile": 16.0,
#         "ninetieth_percentile": 13.2,
#         "seventy_fifth_percentile": 10.0,
#         "fiftieth_percentile": 6.8,
#         "tenth_percentile": 4.3,
#         "local_site_name": "Memphis NCORE site",
#         "site_address": "6388 Haley Rd. (Shelby Farms NCORE site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "47",
#         "county_code": "157",
#         "site_number": "0100",
#         "parameter_code": "88101",
#         "poc": 1,
#         "latitude": 35.16126,
#         "longitude": -89.87065,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "7",
#         "sample_duration": "24 HOUR",
#         "pollutant_standard": "PM25 Annual 2024",
#         "metric_used": "Quarterly Means of Daily Means",
#         "method": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "year": 2021,
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 119,
#         "observation_percent": 98.0,
#         "validity_indicator": "Y",
#         "valid_day_count": 119,
#         "required_day_count": 122,
#         "exceptional_data_count": 0,
#         "null_observation_count": 3,
#         "primary_exceedance_count": 37,
#         "secondary_exceedance_count": 6,
#         "certification_indicator": "Certified",
#         "arithmetic_mean": 7.956303,
#         "standard_deviation": 3.907699,
#         "first_max_value": 25.5,
#         "first_max_datetime": "2021-08-02 00:00",
#         "second_max_value": 24.5,
#         "second_max_datetime": "2021-07-21 00:00",
#         "third_max_value": 18.2,
#         "third_max_datetime": "2021-07-30 00:00",
#         "fourth_max_value": 18.0,
#         "fourth_max_datetime": "2021-08-08 00:00",
#         "first_max_nonoverlap_value": null,
#         "first_max_n_o_datetime": null,
#         "second_max_nonoverlap_value": null,
#         "second_max_n_o_datetime": null,
#         "ninety_ninth_percentile": 24.5,
#         "ninety_eighth_percentile": 18.2,
#         "ninety_fifth_percentile": 15.5,
#         "ninetieth_percentile": 12.7,
#         "seventy_fifth_percentile": 10.1,
#         "fiftieth_percentile": 6.9,
#         "tenth_percentile": 4.2,
#         "local_site_name": "Near Road Site at Southwest Tennessee Community College",
#         "site_address": "5767 Macon Cove (Near Road Site)",
#         "state": "Tennessee",
#         "county": "Shelby",
#         "city": "Memphis",
#         "cbsa_code": "32820",
#         "cbsa": "Memphis, TN-MS-AR",
#         "date_of_last_change": "2024-05-18"
#     }
# ]
